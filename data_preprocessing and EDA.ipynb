# %% [markdown]
# # Required Features
#
# 1. Links
# 2. Restaurant Names
# 3. Location & Accessibility (Address)
# 4. Cuisine Type
# 5. Price Range (Per 2)
# 6. Reviews & Ratings (Out of 5)
# 7. Opening Hours & Reservation Policies (Timings)
# 8. Special Features
# 9. Signature Dishes
# 10. Service Quality--------(excluded)
# 11. Dietary Preferences
# 12. Hygiene & Safety
# 13. Crowd & Wait Time-----------(excluded)
# 14. Family-Friendliness-------------(excluded)

# %%
import pandas as pd

df1 = pd.read_csv('restaurants_dataset (1).csv')

df2 = pd.read_csv('zomato_v3.csv')

df_combined = pd.concat([df1, df2], ignore_index=True)

df_combined.to_csv('New_total.csv', index=False)

# %%
df=pd.read_csv("New_total.csv")
df.head()
# Out:
#                                                links  \
# 0  https://www.zomato.com/hyderabad/mekong-hitech...
# 1  https://www.zomato.com/hyderabad/makau-jubilee...
# 2  https://www.zomato.com/hyderabad/by-the-bottle...
# 3  https://www.zomato.com/hyderabad/aura-cafe-inf...
# 4  https://www.zomato.com/hyderabad/stone-waters-...
#
#                              names       ratings  \
# 0                           Mekong    -star-fill
# 1                            Makau  4.2star-fill
# 2                    By The Bottle  4.2star-fill
# 3         Aura Cafe & Infusion Bar  4.4star-fill
# 4  Stone Waters - Kitchen & Lounge  4.2star-fill
#
#                                      price for two  \
# 0                  ₹2,200 for two people (approx.)
# 1     ₹2,200 for two people (approx.) with alcohol
# 2     ₹1,400 for two people (approx.) with alcohol
# 3  ₹2,000 for two people (approx.) Without alcohol
# 4  ₹2,000 for two people (approx.) Without alcohol
#
#                                              cuisine images  \
# 0  Chinese, Asian, Sushi, Thai, Burmese, Vietname...    NaN
# 1  North Indian, Beverages, Asian, Desserts, Cont...    NaN
# 2  Continental, Chinese, North Indian, Italian, P...    NaN
# 3  Coffee, Italian, Chinese, Oriental, Continenta...    NaN
# 4            North Indian, Continental, Asian, Pizza    NaN
#
#                 opening & closing time                           location  \
# 0  12noon – 3pm, 6:30pm – 11pm (Today)             Hitech City, Hyderabad
# 1                12noon – 11pm (Today)  Road 36, Jubilee Hills, Hyderabad
# 2          12noon – 12midnight (Today)  Road 36, Jubilee Hills, Hyderabad
# 3            10:30am – 11:30pm (Today)           Jubilee Hills, Hyderabad
# 4          3:30pm – 12midnight (Today)           Jubilee Hills, Hyderabad
#
#                                     signature dishes  \
# 0                                      Not available
# 1  Thai Green Curry, Mocktail, Cheesecake, Prawns...
# 2  Crispy Shrimp, Peri Peri Prawn, Sangria, Chick...
# 3  Contadina Pizza, Turkey Sandwich, Chicken Croq...
# 4  Panneer Butter Masala, Alfredo Pasta, Lasagna,...
#
#                                     special features  \
# 0                                      Not available
# 1  Good Music Beautiful Ambiance, Trained Staff, ...
# 2  Rooftop Ambience, Awesome Music, Amazing Music...
# 3  Good Foods and Fresh Juices, Couple Friendly, ...
# 4  Soulful Music, Live Band Performance, Singer, ...
#
#                               safety measures  \
# 0                               Not available
# 1                               Not available
# 2                               Not available
# 3  Well Sanitized Kitchen, Daily Temp. Checks
# 4                               Not available
#
#                                              address
# 0  Survey 64, 15, 24, 25 & 26, Huda Techno Enclav...
# 1  Plot 732, 8-2-293/82/A/732, CBI Colony, Road 3...
# 2          1217/A, Road 36, Jubilee Hills, Hyderabad
# 3     Plot 280-A, Road 10C, Jubilee Hills, Hyderabad
# 4  Shop 1299, B1, 5th Floor, Aruna Arcade, Road 1...

# %%
duplicates = df[df.duplicated(subset=['address'], keep=False)]

print(duplicates)
# Out:
#                                                   links  \
# 0     https://www.zomato.com/hyderabad/mekong-hitech...
# 1     https://www.zomato.com/hyderabad/makau-jubilee...
# 2     https://www.zomato.com/hyderabad/by-the-bottle...
# 3     https://www.zomato.com/hyderabad/aura-cafe-inf...
# 4     https://www.zomato.com/hyderabad/stone-waters-...
# ...                                                 ...
# 8461  https://www.zomato.com/hyderabad/amnesia-loung...
# 8462  https://www.zomato.com/hyderabad/air-live-jubi...
# 8463  https://www.zomato.com/hyderabad/insomnia-jubi...
# 8464  https://www.zomato.com/hyderabad/noho-progress...
# 8465  https://www.zomato.com/hyderabad/hard-rock-caf...
#
#                                 names       ratings  \
# 0                              Mekong    -star-fill
# 1                               Makau  4.2star-fill
# 2                       By The Bottle  4.2star-fill
# 3            Aura Cafe & Infusion Bar  4.4star-fill
# 4     Stone Waters - Kitchen & Lounge  4.2star-fill
# ...                               ...           ...
# 8461               Amnesia Lounge Bar  4.2star-fill
# 8462                         Air Live  4.3star-fill
# 8463                         Insomnia  4.2star-fill
# 8464   Noho - Progressive Asian House  4.4star-fill
# 8465                   Hard Rock Cafe  4.4star-fill
#
#                                         price for two  \
# 0                     ₹2,200 for two people (approx.)
# 1        ₹2,200 for two people (approx.) with alcohol
# 2        ₹1,400 for two people (approx.) with alcohol
# 3     ₹2,000 for two people (approx.) Without alcohol
# 4     ₹2,000 for two people (approx.) Without alcohol
# ...                                               ...
# 8461     ₹1,800 for two people (approx.) with alcohol
# 8462     ₹3,500 for two people (approx.) with alcohol
# 8463     ₹1,900 for two people (approx.) with alcohol
# 8464     ₹3,000 for two people (approx.) with alcohol
# 8465     ₹2,500 for two people (approx.) with alcohol
#
#                                                 cuisine images  \
# 0     Chinese, Asian, Sushi, Thai, Burmese, Vietname...    NaN
# 1     North Indian, Beverages, Asian, Desserts, Cont...    NaN
# 2     Continental, Chinese, North Indian, Italian, P...    NaN
# 3     Coffee, Italian, Chinese, Oriental, Continenta...    NaN
# 4               North Indian, Continental, Asian, Pizza    NaN
# ...                                                 ...    ...
# 8461  Bar Food, American, Pasta, Street Food, Pizza,...    NaN
# 8462  North Indian, Italian, Asian, Continental, Piz...    NaN
# 8463  North Indian, Italian, Chinese, Finger Food, C...    NaN
# 8464  Bar Food, Asian, Japanese, Continental, Orient...    NaN
# 8465  American, Continental, Italian, Wraps, Burger,...    NaN
#
#                       opening & closing time  \
# 0        12noon – 3pm, 6:30pm – 11pm (Today)
# 1                      12noon – 11pm (Today)
# 2                12noon – 12midnight (Today)
# 3                  10:30am – 11:30pm (Today)
# 4                3:30pm – 12midnight (Today)
# ...                                      ...
# 8461                12noon – 12:30am (Today)
# 8462                    12noon – 1am (Today)
# 8463                    12noon – 1am (Today)
# 8464  12noon – 3:30pm, 7pm – 12:30am (Today)
# 8465                    12noon – 1am (Today)
#
#                                     location  \
# 0                     Hitech City, Hyderabad
# 1          Road 36, Jubilee Hills, Hyderabad
# 2          Road 36, Jubilee Hills, Hyderabad
# 3                   Jubilee Hills, Hyderabad
# 4                   Jubilee Hills, Hyderabad
# ...                                      ...
# 8461       Road 36, Jubilee Hills, Hyderabad
# 8462       Road 36, Jubilee Hills, Hyderabad
# 8463       Road 36, Jubilee Hills, Hyderabad
# 8464                Jubilee Hills, Hyderabad
# 8465  GVK One Mall, Banjara Hills, Hyderabad
#
#                                        signature dishes  \
# 0                                         Not available
# 1     Thai Green Curry, Mocktail, Cheesecake, Prawns...
# 2     Crispy Shrimp, Peri Peri Prawn, Sangria, Chick...
# 3     Contadina Pizza, Turkey Sandwich, Chicken Croq...
# 4     Panneer Butter Masala, Alfredo Pasta, Lasagna,...
# ...                                                 ...
# 8461  Whiskey Cocktail, Tandoori Veg Platter, Litchi...
# 8462  Jalapeno Cheeseballs, Crispy French Fries, Vir...
# 8463  Cheesy Corn, Paper Chicken, Mutton Balls, Chil...
# 8464                                      Not available
# 8465  Chicken Fritters, Crispy Bacon, Kiwi Mojito, F...
#
#                                        special features  \
# 0                                         Not available
# 1     Good Music Beautiful Ambiance, Trained Staff, ...
# 2     Rooftop Ambience, Awesome Music, Amazing Music...
# 3     Good Foods and Fresh Juices, Couple Friendly, ...
# 4     Soulful Music, Live Band Performance, Singer, ...
# ...                                                 ...
# 8461  Afforable, Fusion Menu, Good Bartenders, Live ...
# 8462  Manager is Cooperative, Thoughtful and Polite ...
# 8463  Club Music, Kid Friendly, Best Club, Best Dj, ...
# 8464                                      Not available
# 8465  Rock Music, Music and Ambience, Band Playing, ...
#
#                                  safety measures  \
# 0                                  Not available
# 1                                  Not available
# 2                                  Not available
# 3     Well Sanitized Kitchen, Daily Temp. Checks
# 4                                  Not available
# ...                                          ...
# 8461                               Not available
# 8462                               Not available
# 8463                               Not available
# 8464                               Not available
# 8465                          Daily Temp. Checks
#
#                                                 address
# 0     Survey 64, 15, 24, 25 & 26, Huda Techno Enclav...
# 1     Plot 732, 8-2-293/82/A/732, CBI Colony, Road 3...
# 2             1217/A, Road 36, Jubilee Hills, Hyderabad
# 3        Plot 280-A, Road 10C, Jubilee Hills, Hyderabad
# 4     Shop 1299, B1, 5th Floor, Aruna Arcade, Road 1...
# ...                                                 ...
# 8461  Plot 1102, 5th Floor, Jaya Chambers, Road 36, ...
# 8462  5th Floor, Odyssey Mall, Road 36, Jubilee Hill...
# 8463  3rd & 4th Floor, Jaya Chambers, Road 36, Jubil...
# 8464  8-2-293/A/1057/G, Ground To 3 Rd Floor, Road 4...
# 8465  Ground Floor, GVK One Mall, Road 1, Banjara Hi...
#
# [7506 rows x 12 columns]

# %%
duplicates = df[df.duplicated()]
print(f"Number of duplicate rows: {len(duplicates)}")
# Out:
# Number of duplicate rows: 5240

# %%
df = df.drop_duplicates(subset=['address'], keep='first')

df.to_csv('modified_file.csv', index=False)

print("Duplicates based on address have been removed.")

# %%
duplicates = df.duplicated()
print(f"Number of duplicate rows: {duplicates.sum()}")

if duplicates.any():
    print("Duplicate rows:")
    print(df[duplicates])
# Out:
# Number of duplicate rows: 5240
# Duplicate rows:
#                                                   links  \
# 501   https://www.zomato.com/hyderabad/mekong-hitech...
# 504   https://www.zomato.com/hyderabad/antera-kitche...
# 505   https://www.zomato.com/hyderabad/x-lounge-hite...
# 506   https://www.zomato.com/hyderabad/makau-jubilee...
# 509   https://www.zomato.com/hyderabad/a19-klub-kitc...
# ...                                                 ...
# 8461  https://www.zomato.com/hyderabad/amnesia-loung...
# 8462  https://www.zomato.com/hyderabad/air-live-jubi...
# 8463  https://www.zomato.com/hyderabad/insomnia-jubi...
# 8464  https://www.zomato.com/hyderabad/noho-progress...
# 8465  https://www.zomato.com/hyderabad/hard-rock-caf...
#
#                                names       ratings  \
# 501                           Mekong    -star-fill
# 504           AnTeRa Kitchen And Bar  4.4star-fill
# 505                         X Lounge  4.4star-fill
# 506                            Makau  4.2star-fill
# 509               A19 Klub & Kitchen  4.2star-fill
# ...                              ...           ...
# 8461              Amnesia Lounge Bar  4.2star-fill
# 8462                        Air Live  4.3star-fill
# 8463                        Insomnia  4.2star-fill
# 8464  Noho - Progressive Asian House  4.4star-fill
# 8465                  Hard Rock Cafe  4.4star-fill
#
#                                         price for two  \
# 501                   ₹2,200 for two people (approx.)
# 504   ₹1,900 for two people (approx.) Without alcohol
# 505      ₹2,000 for two people (approx.) with alcohol
# 506      ₹2,200 for two people (approx.) with alcohol
# 509   ₹2,000 for two people (approx.) Without alcohol
# ...                                               ...
# 8461     ₹1,800 for two people (approx.) with alcohol
# 8462     ₹3,500 for two people (approx.) with alcohol
# 8463     ₹1,900 for two people (approx.) with alcohol
# 8464     ₹3,000 for two people (approx.) with alcohol
# 8465     ₹2,500 for two people (approx.) with alcohol
#
#                                                 cuisine images  \
# 501   Chinese, Asian, Sushi, Thai, Burmese, Vietname...    NaN
# 504   South Indian, North Indian, Biryani, Chinese, ...    NaN
# 505   North Indian, Chinese, Fast Food, Finger Food,...    NaN
# 506   North Indian, Beverages, Asian, Desserts, Cont...    NaN
# 509   Bar Food, Pizza, Fast Food, Finger Food, Birya...    NaN
# ...                                                 ...    ...
# 8461  Bar Food, American, Pasta, Street Food, Pizza,...    NaN
# 8462  North Indian, Italian, Asian, Continental, Piz...    NaN
# 8463  North Indian, Italian, Chinese, Finger Food, C...    NaN
# 8464  Bar Food, Asian, Japanese, Continental, Orient...    NaN
# 8465  American, Continental, Italian, Wraps, Burger,...    NaN
#
#                       opening & closing time  \
# 501      12noon – 3pm, 6:30pm – 11pm (Today)
# 504                 12noon – 11:30pm (Today)
# 505                 12noon – 11:30pm (Today)
# 506                    12noon – 11pm (Today)
# 509                 12noon – 11:30pm (Today)
# ...                                      ...
# 8461                12noon – 12:30am (Today)
# 8462                    12noon – 1am (Today)
# 8463                    12noon – 1am (Today)
# 8464  12noon – 3:30pm, 7pm – 12:30am (Today)
# 8465                    12noon – 1am (Today)
#
#                                            location  \
# 501                          Hitech City, Hyderabad
# 504                           Gachibowli, Hyderabad
# 505                          Hitech City, Hyderabad
# 506               Road 36, Jubilee Hills, Hyderabad
# 509   Sarath City Capital Mall, Kondapur, Hyderabad
# ...                                             ...
# 8461              Road 36, Jubilee Hills, Hyderabad
# 8462              Road 36, Jubilee Hills, Hyderabad
# 8463              Road 36, Jubilee Hills, Hyderabad
# 8464                       Jubilee Hills, Hyderabad
# 8465         GVK One Mall, Banjara Hills, Hyderabad
#
#                                        signature dishes  \
# 501                                       Not available
# 504                                       Not available
# 505                                       Not available
# 506   Thai Green Curry, Mocktail, Cheesecake, Prawns...
# 509                                       Not available
# ...                                                 ...
# 8461  Whiskey Cocktail, Tandoori Veg Platter, Litchi...
# 8462  Jalapeno Cheeseballs, Crispy French Fries, Vir...
# 8463  Cheesy Corn, Paper Chicken, Mutton Balls, Chil...
# 8464                                      Not available
# 8465  Chicken Fritters, Crispy Bacon, Kiwi Mojito, F...
#
#                                        special features     safety measures  \
# 501                                       Not available       Not available
# 504                                       Not available       Not available
# 505   Nice Service, Good Music, Young Crowd, Elabora...       Not available
# 506   Good Music Beautiful Ambiance, Trained Staff, ...       Not available
# 509                                       Not available       Not available
# ...                                                 ...                 ...
# 8461  Afforable, Fusion Menu, Good Bartenders, Live ...       Not available
# 8462  Manager is Cooperative, Thoughtful and Polite ...       Not available
# 8463  Club Music, Kid Friendly, Best Club, Best Dj, ...       Not available
# 8464                                      Not available       Not available
# 8465  Rock Music, Music and Ambience, Band Playing, ...  Daily Temp. Checks
#
#                                                 address
# 501   Survey 64, 15, 24, 25 & 26, Huda Techno Enclav...
# 504   H 1-72/3/6/28/A Grounf & 1St Floor, Konstruct ...
# 505   Plot 1, Survey 64, 6th Floor, Huda Techno Encl...
# 506   Plot 732, 8-2-293/82/A/732, CBI Colony, Road 3...
# 509   5Th Floor, Sarath City Capital Mall, Kondapur,...
# ...                                                 ...
# 8461  Plot 1102, 5th Floor, Jaya Chambers, Road 36, ...
# 8462  5th Floor, Odyssey Mall, Road 36, Jubilee Hill...
# 8463  3rd & 4th Floor, Jaya Chambers, Road 36, Jubil...
# 8464  8-2-293/A/1057/G, Ground To 3 Rd Floor, Road 4...
# 8465  Ground Floor, GVK One Mall, Road 1, Banjara Hi...
#
# [5240 rows x 12 columns]

# %%
df = df.drop_duplicates(subset=['address'], keep='first')

df.to_csv('modified_file.csv', index=False)

print("Duplicates based on address have been removed.")
# Out:
# Duplicates based on address have been removed.

# %%
df["ratings"] = df["ratings"].astype(str).str.replace("star-fill", "", regex=False)

df["ratings"] = pd.to_numeric(df["ratings"], errors='coerce')

df.to_csv("modified_file.csv", index=False)

# %%
df.tail()
# Out:
#                                                   links  \
# 8425  https://www.zomato.com/hyderabad/wisphot-nered...
# 8426  https://www.zomato.com/hyderabad/starvees-sain...
# 8427  https://www.zomato.com/hyderabad/marleys-joint...
# 8428  https://www.zomato.com/hyderabad/paradise-biry...
# 8429  https://www.zomato.com/hyderabad/kairos-bar-ki...
#
#                                        names  ratings  \
# 8425                                 Wisphot      NaN
# 8426                                Starvees      3.5
# 8427                          Marley's Joint      4.0
# 8428  Paradise Biryani - A Legend Since 1953      3.4
# 8429                    Kairos Bar & Kitchen      4.2
#
#                         price for two  \
# 8425    ₹500 for two people (approx.)
# 8426    ₹300 for two people (approx.)
# 8427    ₹300 for two people (approx.)
# 8428  ₹1,000 for two people (approx.)
# 8429  ₹2,000 for two people (approx.)
#
#                                                 cuisine images  \
# 8425                                   Wraps, Fast Food    NaN
# 8426                Fast Food, Beverages, Burger, Shake    NaN
# 8427                                      Burger, Pizza    NaN
# 8428  Biryani, Kebab, North Indian, Rolls, Desserts,...    NaN
# 8429  North Indian, Chinese, Italian, Pizza, Asian, ...    NaN
#
#                              opening & closing time                  location  \
# 8425  12midnight – 6am, 2:45pm – 12midnight (Today)       Neredmet, Hyderabad
# 8426    12midnight – 3am, 11am – 12midnight (Today)  Sainikpuri, Secunderabad
# 8427  12midnight – 4am, 12noon – 12midnight (Today)       Neredmet, Hyderabad
# 8428    12midnight – 1am, 10am – 12midnight (Today)        ECIL, Secunderabad
# 8429                                Opens at 12noon  Sainikpuri, Secunderabad
#
#                                        signature dishes  \
# 8425                                      Not available
# 8426                                      Not available
# 8427  Double Patty Burger, Crispy Chicken, Burgers, ...
# 8428                                      Not available
# 8429                                      Not available
#
#                                        special features     safety measures  \
# 8425                                      Not available       Not available
# 8426                                      Not available       Not available
# 8427  Comforting Atmosphere, Wonderful Presentation,...  Daily Temp. Checks
# 8428  Cute Packaging, Timely Service, Good Taste, Go...       Not available
# 8429                                      Not available       Not available
#
#                                                 address
# 8425               Hyjack Drive-In, Neredmet, Hyderabad
# 8426  Plot 654, Defence Colony, Sainikpuri, Secunder...
# 8427  H 37-38, Plot 650, Defence Colony, Sainikpuri,...
# 8428  Survey 227, Plot 01, Kushaiguda, Keesara Manda...
# 8429  39-179, Vayupuri Sainikpuri, Sainikpuri, Secun...

# %%
df=df.drop(columns=["images"])
df.to_csv("modified_file.csv",index=False)

# %%
df.head()
# Out:
#                                                links  \
# 0  https://www.zomato.com/hyderabad/mekong-hitech...
# 1  https://www.zomato.com/hyderabad/makau-jubilee...
# 2  https://www.zomato.com/hyderabad/by-the-bottle...
# 3  https://www.zomato.com/hyderabad/aura-cafe-inf...
# 4  https://www.zomato.com/hyderabad/stone-waters-...
#
#                              names  ratings  \
# 0                           Mekong      NaN
# 1                            Makau      4.2
# 2                    By The Bottle      4.2
# 3         Aura Cafe & Infusion Bar      4.4
# 4  Stone Waters - Kitchen & Lounge      4.2
#
#                                      price for two  \
# 0                  ₹2,200 for two people (approx.)
# 1     ₹2,200 for two people (approx.) with alcohol
# 2     ₹1,400 for two people (approx.) with alcohol
# 3  ₹2,000 for two people (approx.) Without alcohol
# 4  ₹2,000 for two people (approx.) Without alcohol
#
#                                              cuisine  \
# 0  Chinese, Asian, Sushi, Thai, Burmese, Vietname...
# 1  North Indian, Beverages, Asian, Desserts, Cont...
# 2  Continental, Chinese, North Indian, Italian, P...
# 3  Coffee, Italian, Chinese, Oriental, Continenta...
# 4            North Indian, Continental, Asian, Pizza
#
#                 opening & closing time                           location  \
# 0  12noon – 3pm, 6:30pm – 11pm (Today)             Hitech City, Hyderabad
# 1                12noon – 11pm (Today)  Road 36, Jubilee Hills, Hyderabad
# 2          12noon – 12midnight (Today)  Road 36, Jubilee Hills, Hyderabad
# 3            10:30am – 11:30pm (Today)           Jubilee Hills, Hyderabad
# 4          3:30pm – 12midnight (Today)           Jubilee Hills, Hyderabad
#
#                                     signature dishes  \
# 0                                      Not available
# 1  Thai Green Curry, Mocktail, Cheesecake, Prawns...
# 2  Crispy Shrimp, Peri Peri Prawn, Sangria, Chick...
# 3  Contadina Pizza, Turkey Sandwich, Chicken Croq...
# 4  Panneer Butter Masala, Alfredo Pasta, Lasagna,...
#
#                                     special features  \
# 0                                      Not available
# 1  Good Music Beautiful Ambiance, Trained Staff, ...
# 2  Rooftop Ambience, Awesome Music, Amazing Music...
# 3  Good Foods and Fresh Juices, Couple Friendly, ...
# 4  Soulful Music, Live Band Performance, Singer, ...
#
#                               safety measures  \
# 0                               Not available
# 1                               Not available
# 2                               Not available
# 3  Well Sanitized Kitchen, Daily Temp. Checks
# 4                               Not available
#
#                                              address
# 0  Survey 64, 15, 24, 25 & 26, Huda Techno Enclav...
# 1  Plot 732, 8-2-293/82/A/732, CBI Colony, Road 3...
# 2          1217/A, Road 36, Jubilee Hills, Hyderabad
# 3     Plot 280-A, Road 10C, Jubilee Hills, Hyderabad
# 4  Shop 1299, B1, 5th Floor, Aruna Arcade, Road 1...

# %%
import re
import numpy as np

def convert_price_to_int(price_str):
    cleaned_price = re.sub(r'[₹,]', '', price_str)
    cleaned_price = re.sub(r'[^0-9]', '', cleaned_price)
    if cleaned_price:
        return int(cleaned_price)
    else:
        return np.nan

df['price for two'] = df['price for two'].apply(convert_price_to_int)

df.to_csv('cleaned_dataset.csv', index=False)

# %%
def extract_timings(timing):
    try:
        parts = timing.split(',')
        open_times = []
        close_times = []

        for part in parts:
            if '–' in part:
                times = part.split('–')
                open_times.append(times[0].strip())
                close_times.append(times[1].split('(')[0].strip())

        if not open_times or not close_times:
            return None, None

        return open_times[0], close_times[-1]

    except IndexError:
        return None, None

df['Opening Times'], df['Closing Times'] = zip(*df['opening & closing time'].apply(extract_timings))

df.head()
# Out:
#                                                links  \
# 0  https://www.zomato.com/hyderabad/mekong-hitech...
# 1  https://www.zomato.com/hyderabad/makau-jubilee...
# 2  https://www.zomato.com/hyderabad/by-the-bottle...
# 3  https://www.zomato.com/hyderabad/aura-cafe-inf...
# 4  https://www.zomato.com/hyderabad/stone-waters-...
#
#                              names  ratings  price for two  \
# 0                           Mekong      NaN         2200.0
# 1                            Makau      4.2         2200.0
# 2                    By The Bottle      4.2         1400.0
# 3         Aura Cafe & Infusion Bar      4.4         2000.0
# 4  Stone Waters - Kitchen & Lounge      4.2         2000.0
#
#                                              cuisine  \
# 0  Chinese, Asian, Sushi, Thai, Burmese, Vietname...
# 1  North Indian, Beverages, Asian, Desserts, Cont...
# 2  Continental, Chinese, North Indian, Italian, P...
# 3  Coffee, Italian, Chinese, Oriental, Continenta...
# 4            North Indian, Continental, Asian, Pizza
#
#                 opening & closing time                           location  \
# 0  12noon – 3pm, 6:30pm – 11pm (Today)             Hitech City, Hyderabad
# 1                12noon – 11pm (Today)  Road 36, Jubilee Hills, Hyderabad
# 2          12noon – 12midnight (Today)  Road 36, Jubilee Hills, Hyderabad
# 3            10:30am – 11:30pm (Today)           Jubilee Hills, Hyderabad
# 4          3:30pm – 12midnight (Today)           Jubilee Hills, Hyderabad
#
#                                     signature dishes  \
# 0                                      Not available
# 1  Thai Green Curry, Mocktail, Cheesecake, Prawns...
# 2  Crispy Shrimp, Peri Peri Prawn, Sangria, Chick...
# 3  Contadina Pizza, Turkey Sandwich, Chicken Croq...
# 4  Panneer Butter Masala, Alfredo Pasta, Lasagna,...
#
#                                     special features  \
# 0                                      Not available
# 1  Good Music Beautiful Ambiance, Trained Staff, ...
# 2  Rooftop Ambience, Awesome Music, Amazing Music...
# 3  Good Foods and Fresh Juices, Couple Friendly, ...
# 4  Soulful Music, Live Band Performance, Singer, ...
#
#                               safety measures  \
# 0                               Not available
# 1                               Not available
# 2                               Not available
# 3  Well Sanitized Kitchen, Daily Temp. Checks
# 4                               Not available
#
#                                              address Opening Times  \
# 0  Survey 64, 15, 24, 25 & 26, Huda Techno Enclav...        12noon
# 1  Plot 732, 8-2-293/82/A/732, CBI Colony, Road 3...        12noon
# 2          1217/A, Road 36, Jubilee Hills, Hyderabad        12noon
# 3     Plot 280-A, Road 10C, Jubilee Hills, Hyderabad       10:30am
# 4  Shop 1299, B1, 5th Floor, Aruna Arcade, Road 1...        3:30pm
#
#   Closing Times
# 0          11pm
# 1          11pm
# 2    12midnight
# 3       11:30pm
# 4    12midnight

# %%
df=df.drop(columns=["opening & closing time"])
df.to_csv('cleaned_dataset.csv', index=False)

# %%
veg_df = pd.read_csv('pure_veg.csv')

veg_links_set = set(veg_df['restaurant_links'])

df['Veg'] = df['links'].apply(lambda link: 1 if link in veg_links_set else 0)

df.head()
# Out:
#                                                links  \
# 0  https://www.zomato.com/hyderabad/mekong-hitech...
# 1  https://www.zomato.com/hyderabad/makau-jubilee...
# 2  https://www.zomato.com/hyderabad/by-the-bottle...
# 3  https://www.zomato.com/hyderabad/aura-cafe-inf...
# 4  https://www.zomato.com/hyderabad/stone-waters-...
#
#                              names  ratings  price for two  \
# 0                           Mekong      NaN         2200.0
# 1                            Makau      4.2         2200.0
# 2                    By The Bottle      4.2         1400.0
# 3         Aura Cafe & Infusion Bar      4.4         2000.0
# 4  Stone Waters - Kitchen & Lounge      4.2         2000.0
#
#                                              cuisine  \
# 0  Chinese, Asian, Sushi, Thai, Burmese, Vietname...
# 1  North Indian, Beverages, Asian, Desserts, Cont...
# 2  Continental, Chinese, North Indian, Italian, P...
# 3  Coffee, Italian, Chinese, Oriental, Continenta...
# 4            North Indian, Continental, Asian, Pizza
#
#                             location  \
# 0             Hitech City, Hyderabad
# 1  Road 36, Jubilee Hills, Hyderabad
# 2  Road 36, Jubilee Hills, Hyderabad
# 3           Jubilee Hills, Hyderabad
# 4           Jubilee Hills, Hyderabad
#
#                                     signature dishes  \
# 0                                      Not available
# 1  Thai Green Curry, Mocktail, Cheesecake, Prawns...
# 2  Crispy Shrimp, Peri Peri Prawn, Sangria, Chick...
# 3  Contadina Pizza, Turkey Sandwich, Chicken Croq...
# 4  Panneer Butter Masala, Alfredo Pasta, Lasagna,...
#
#                                     special features  \
# 0                                      Not available
# 1  Good Music Beautiful Ambiance, Trained Staff, ...
# 2  Rooftop Ambience, Awesome Music, Amazing Music...
# 3  Good Foods and Fresh Juices, Couple Friendly, ...
# 4  Soulful Music, Live Band Performance, Singer, ...
#
#                               safety measures  \
# 0                               Not available
# 1                               Not available
# 2                               Not available
# 3  Well Sanitized Kitchen, Daily Temp. Checks
# 4                               Not available
#
#                                              address Opening Times  \
# 0  Survey 64, 15, 24, 25 & 26, Huda Techno Enclav...        12noon
# 1  Plot 732, 8-2-293/82/A/732, CBI Colony, Road 3...        12noon
# 2          1217/A, Road 36, Jubilee Hills, Hyderabad        12noon
# 3     Plot 280-A, Road 10C, Jubilee Hills, Hyderabad       10:30am
# 4  Shop 1299, B1, 5th Floor, Aruna Arcade, Road 1...        3:30pm
#
#   Closing Times  Veg
# 0          11pm    0
# 1          11pm    0
# 2    12midnight    0
# 3       11:30pm    0
# 4    12midnight    0

# %%
df.to_csv('cleaned_dataset.csv', index=False)

# %%
veg_count = df[df['Veg'] == 1].shape[0]

print(f'Total number of vegetarian restaurants: {veg_count}')
# Out:
# Total number of vegetarian restaurants: 342

# %%
df.shape
# Out:
# (2420, 13)

# %%
df.rename(columns={'price for two': 'price_for_two'}, inplace=True)

df.to_csv('modified_file.csv', index=False)

print("Column name changed successfully.")
# Out:
# Column name changed successfully.

# %%
duplicates = df[df.duplicated(subset=['address'], keep=False)]

print(duplicates)
# Out:
# Empty DataFrame
# Columns: [links, names, ratings, price_for_two, cuisine, location, signature dishes, special features, safety measures, address, Opening Times, Closing Times, Veg]
# Index: []

# %%
df = pd.read_csv('final.csv')
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from wordcloud import WordCloud

cuisine_series = df['cuisine'].dropna()

cuisines_text = " ".join(cuisine_series)

wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white',
    colormap='viridis',
    max_words=100
).generate(cuisines_text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
cuisine_counts = df['cuisine'].value_counts().head(20)

plt.figure(figsize=(12, 6))
plt.bar(cuisine_counts.index, cuisine_counts.values)
plt.xlabel('Cuisine')
plt.ylabel('Number of Restaurants')
plt.title('Top 20 Most Popular Cuisines')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='price_for_two', y='rating', data=df)
plt.xlabel('Price for Two')
plt.ylabel('Ratings')
plt.title('Price vs. Ratings')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['price_for_two'], bins=20, kde=True)
plt.xlabel('Price for Two')
plt.ylabel('Number of Restaurants')
plt.title('Distribution of Price Range')
plt.show()

# %%
df['location'] = df['location'].str.replace(', Hyderabad', '', regex=False)

# %%
location_counts = df['location'].value_counts().head(10)

plt.figure(figsize=(12, 6))
plt.bar(location_counts.index, location_counts.values)
plt.xlabel('Location')
plt.ylabel('Number of Restaurants')
plt.title('Top 10 Locations with Most Restaurants')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
restaurant_name_series = df['name'].dropna()

restaurant_names_text = " ".join(restaurant_name_series)

wordcloud = WordCloud(
    width=800,
    height=400,
    background_color='white',
    colormap='viridis',
    max_words=100
).generate(restaurant_names_text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
df['rating'] = df['rating'].round(0).astype(int)

def categorize_rating(rating):
    if rating >= 4:
        return 'Excellent'
    elif rating >= 3:
        return 'Good'
    else:
        return 'Poor'

df['rating_category'] = df['rating'].apply(categorize_rating)

rating_counts = df['rating_category'].value_counts()

colors = {'Excellent': 'green', 'Good': 'yellow', 'Poor': 'red'}

plt.figure(figsize=(8, 6))
plt.bar(
    rating_counts.index,
    rating_counts.values,
    color=[colors[category] for category in rating_counts.index]
)
plt.xlabel('Rating Category')
plt.ylabel('Number of Restaurants')
plt.title('Distribution of Restaurant Ratings (Rounded to Integers)')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='rating_category', y='price_for_two', data=df)
plt.xlabel('Rating Category')
plt.ylabel('Price for Two')
plt.title('Price Distribution by Rating Category')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='rating_category', y='price_for_two', data=df)
plt.xlabel('Rating Category')
plt.ylabel('Price for Two')
plt.title('Price Distribution by Rating Category (Violin Plot)')
plt.show()

# %%
veg_count = df[df['Veg'] == 1].shape[0]
non_veg_count = df[df['Veg'] == 0].shape[0]

labels = ['Pure Vegetarian', 'Both']
sizes = [veg_count, non_veg_count]

colors = ['lightgreen', 'lightcoral']

plt.figure(figsize=(8, 8))
plt.pie(
    sizes,
    labels=labels,
    colors=colors,
    autopct='%1.1f%%',
    startangle=90,
    shadow=True,
    wedgeprops={'edgecolor': 'black'}
)

plt.title('Proportion of Pure Vegetarian and Non-Vegetarian Restaurants')
plt.axis('equal')

plt.show()

# %%
#Cuisine Type
#df['cuisine'].value_counts().plot(kind='bar')

# %%
# import folium
# map = folium.Map(location=[latitude, longitude], zoom_start=12)
# for _, row in df.iterrows():
#     folium.Marker([row['lat'], row['lon']], popup=row['restaurant_name']).add_to(map)
# map

# %%
# # Pivot the data to create a user-item matrix
# user_item_matrix = df.pivot(index='user_id', columns='names', values='rating').fillna(0)

# # Display the user-item matrix
# # print(user_item_matrix)

# import seaborn as sns
# sns.heatmap(user_item_matrix, cmap='coolwarm')

# %%
from geopy.geocoders import Nominatim
import time

geolocator = Nominatim(user_agent="restaurant_locator")

def get_coordinates(address):
    try:
        location = geolocator.geocode(address)
        if location:
            return location.latitude, location.longitude
        else:
            return None, None
    except Exception as e:
        return None, None

df['latitude'] = None
df['longitude'] = None

for idx, row in df.iterrows():
    address = row['address']
    lat, lon = get_coordinates(address)
    df.at[idx, 'latitude'] = lat
    df.at[idx, 'longitude'] = lon

    time.sleep(1)

# %%
import folium

map = folium.Map(location=[17.385044, 78.486671], zoom_start=12)

for _, row in df.iterrows():
    if pd.notnull(row['latitude']) and pd.notnull(row['longitude']):
        folium.Marker([row['latitude'], row['longitude']], popup=row['names']).add_to(map)

map.save('restaurants_map.html')
